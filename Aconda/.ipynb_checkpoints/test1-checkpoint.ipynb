# %%
num = [2,4,6,8,10]
for i in range(len(num)):
    num[i]=num[i]*2
print(num)
# Out:
# [4, 8, 12, 16, 20]

# %%
for i,n in enumerate(num):
    num[i]=n*2
print(num)
# Out:
# [8, 16, 24, 32, 40]

# %%
np.random.randint(2,4,(2,4))
# Out:
# array([[2, 3, 3, 3],
#        [3, 3, 2, 2]])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#创建数据
np.random.seed(1)
x=np.arange(10)
y=np.random.rand(10)
#显示图形
plt.plot(x,y)
plt.show()
